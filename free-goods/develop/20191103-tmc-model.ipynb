# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
#from pivottablejs import pivot_ui
import sys
import warnings

warnings.filterwarnings("ignore")

# %%
# Load

# %%
df = pd.read_pickle("../data/free-goods-201909ytd.pickel")

# %%
df.head()
# Out:
#    mnth doc_type     csr OrderSourceCode PriceMethod       vpa SalesDivision  \
# 0     9       SO  BMAR04               T           Q  CAPPROGM           AAD
# 1     9       SO  BMAR04               T           Q  CAPPROGM           AAD
# 2     9       SE    ANUR               W           Q   DR09FCS           AAD
# 3     9       SO  BMAR04               T           Q  CAPPROGM           AAD
# 4     9       SE  WBINNI               E           Q   DR05TCS           AAD
#
#   MajorProductClass price_adj supplier  ...  mpc MarketClass_New specialty  \
# 0               013       NaN   MEDICM  ...  013          PVTPRC      GENP
# 1               013       NaN   MEDICM  ...  013          PVTPRC      GENP
# 2               013       NaN   MEDICM  ...  013          PVTPRC      GENP
# 3               010       NaN   JINSTR  ...  010          PVTPRC      GENP
# 4               010       NaN   JINSTR  ...  010          PVTPRC      GENP
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121911 entries, 0 to 121910
# Data columns (total 23 columns):
# mnth                 121911 non-null int64
# doc_type             121911 non-null category
# csr                  121911 non-null category
# OrderSourceCode      121911 non-null category
# PriceMethod          121911 non-null category
# vpa                  89514 non-null category
# SalesDivision        121911 non-null category
# MajorProductClass    121911 non-null category
# price_adj            29155 non-null category
# supplier             121911 non-null object
# StockingType         121911 non-null category
# category             121911 non-null category
# Label                121911 non-null category
# mpc                  121911 non-null object
# MarketClass_New      121911 non-null category
# specialty            121911 non-null category
# fg_act_ind           121911 non-null bool
# fg_redeem_ind        121911 non-null bool
# ...

# %%
df.groupby('doc_type')['fg_redeem_ind'].count().sort_values(ascending=False).plot('bar')

# %%
df.groupby('OrderSourceCode')['fg_redeem_ind'].count().sort_values(ascending=False).plot('bar')

# %%
df.groupby('SalesDivision')['fg_redeem_ind'].count().sort_values(ascending=False).plot('bar')

# %%
df.groupby('PriceMethod')['fg_redeem_ind'].count().sort_values(ascending=False).plot('bar')

# %%
df.groupby('MarketClass_New')['fg_redeem_ind'].count().sort_values(ascending=False).plot('bar')

# %%
#look into GPS model
df.
# Out:
#   File "<ipython-input-11-01ac1cd0ede8>", line 2
#     df.
#        ^
# SyntaxError: invalid syntax
